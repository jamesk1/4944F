# %%
# Robocop Midterm Parser
# Change article names to get word counts of specific article WSJ, NYT, etc.

import pandas as pd
import csv
import codecs
import re
import nltk
import collections
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import itertools

# Linguistic Inquiry and Word Count dataset
# Pronouns, Personal Pronouns, Adverbs -> stop words
# Positive, Negative, Anxious, Anger, Sad, Religious
x = pd.read_csv("projectData.csv").fillna(value='')

# wall street journal articles - real
with codecs.open('bbc.csv','r',encoding='utf8') as f:
    text = f.read()    
largeSample = []
test = text.split()

for i in test:
    i = re.sub(r"http\D+[0-9]+","", i)
    i = re.sub('[^A-Za-z0-9]+', '', i)
    largeSample.append(i)    

print len(largeSample)
# Out:
# 55547

# %%
# bb news articles - fake
with codecs.open('rt.csv','r',encoding='utf8') as r:
    fake = r.read()    
fakeSample = []
fakeN = fake.split()

for i in fakeN:
    i = re.sub(r"http\D+[0-9]+","", i)
    i = re.sub('[^A-Za-z0-9]+', '', i)
    fakeSample.append(i)

# counter for Pronouns in fake sample without stop words
numPron2 = 0
for k in x['Pronoun']:
    for i in fakeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPron2 = numPron2 + len(found)
            if k == i:
                numPron2 = numPron2 + 1           
print "The number of pronouns in the fake news articles:", (numPron2)

# counter for Ppronouns in fake sample without stop words
numPpron2 = 0
for k in x['Ppron']:
    for i in fakeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPpron2 = numPpron2 + len(found)
            if k == i:
                numPpron2 = numPpron2 + 1            
print "The number of personal pronouns in the fake news articles:", (numPpron2)

# counter for Adverbs in fake sample with stop words
numAdverb2 = 0
for k in x['Adverbs']:
    for i in fakeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAdverb2 = numAdverb2 + len(found)
            if k == i:
                numAdverb2 = numAdverb2 + 1         
print "The number of adverbs in the fake news articles:", (numAdverb2)
    
# stop words excluded to check other non-pronoun columns
wordsFiltered2 = []
stopWords = set(stopwords.words('english'))
for w in fakeSample:
    if w not in stopWords:
        wordsFiltered2.append(w)    

# counter for Positive emotion in fake sample without stop words
numPosemo2 = 0
for k in x['Posemo']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPosemo2 = numPosemo2 + len(found)
            if k == i:
                numPosemo2 = numPosemo2 + 1         
print "The number of positive emotion words in the fake news articles:", (numPosemo2)

# counter for Negative emotion in fake sample without stop words
numNegemo2 = 0
for k in x['Negemo']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numNegemo2 = numNegemo2 + len(found)
            if k == i:
                numNegemo2 = numNegemo2 + 1         
print "The number of negative emotion words in the fake news articles:", (numNegemo2)

# counter for anxious emotion in fake sample without stop words
numAnx2 = 0
for k in x['Anx']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAnx2 = numAnx2 + len(found)
            if k == i:
                numAnx2 = numAnx2 + 1         
print "The number of anxious emotion words in the fake news articles:", (numAnx2)

# counter for anger emotion in fake sample without stop words
numAng2 = 0
for k in x['Anger']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAn2g = numAng2 + len(found)
            if k == i:
                numAng2 = numAng2 + 1         
print "The number of anger emotion words in the fake news articles:", (numAng2)

# counter for sad emotion in fake sample without stop words
numSad2 = 0
for k in x['Sad']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numSad2 = numSad2 + len(found)
            if k == i:
                numSad2 = numSad2 + 1         
print "The number of sad emotion words in the fake news articles:", (numSad2)

# counter for religious emotion in fake sample without stop words
numRelig2 = 0
for k in x['Relig']:
    for i in wordsFiltered2:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numRelig2 = numRelig2 + len(found)
            if k == i:
                numRelig2 = numRelig2 + 1         
print "The number of religious emotion words in the fake news articles:", (numRelig2)
# Out:
# The number of pronouns in the fake news articles: 2995
# The number of personal pronouns in the fake news articles: 970
# The number of adverbs in the fake news articles: 1170
# The number of positive emotion words in the fake news articles: 838
# The number of negative emotion words in the fake news articles: 823
# The number of anxious emotion words in the fake news articles: 412
# The number of anger emotion words in the fake news articles: 103
# The number of sad emotion words in the fake news articles: 251
# The number of religious emotion words in the fake news articles: 119

# %%
print "WSJ including stop words", len(largeSample)
print "BB including stop words", len(fakeSample)
# Out:
# WSJ including stop words 55547
# BB including stop words 51917

# %%
# method for getting N-Grams, counting occurrences of same type of n-gram 1, 2, 3
def getNGrams(words, n):
    ngrams = []
    for i in range(len(words)-(n-1)):
        ngrams.append(words[i:i+n])
    return ngrams

# testing N-Grams of 3
testNGrams = getNGrams(largeSample, 3)
#print testNGrams

# %%
# counter for Pronouns in large sample with stop words
numPron = 0
for k in x['Pronoun']:
    for i in largeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPron = numPron + len(found)
            if k == i:
                numPron = numPron + 1           
print "The number of pronouns in the real news articles:", (numPron)

# counter for Ppronouns in large sample with stop words
numPpron = 0
for k in x['Ppron']:
    for i in largeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPpron = numPpron + len(found)
            if k == i:
                numPpron = numPpron + 1            
print "The number of personal pronouns in the real news articles:", (numPpron)

# counter for Adverbs in large sample with stop words
numAdverb = 0
for k in x['Adverbs']:
    for i in largeSample:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAdverb = numAdverb + len(found)
            if k == i:
                numAdverb = numAdverb + 1         
print "The number of adverbs in the real news articles:", (numAdverb)
    
# stop words excluded to check other non-pronoun columns
wordsFiltered = []
stopWords = set(stopwords.words('english'))
for w in largeSample:
    if w not in stopWords:
        wordsFiltered.append(w)    

# counter for Positive emotion in large sample without stop words
numPosemo = 0
for k in x['Posemo']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numPosemo = numPosemo + len(found)
            if k == i:
                numPosemo = numPosemo + 1         
print "The number of positive emotion words in the real news articles:", (numPosemo)

# counter for Negative emotion in large sample without stop words
numNegemo = 0
for k in x['Negemo']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numNegemo = numNegemo + len(found)
            if k == i:
                numNegemo = numNegemo + 1         
print "The number of negative emotion words in the real news articles:", (numNegemo)

# counter for anxious emotion in large sample without stop words
numAnx = 0
for k in x['Anx']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAnx = numAnx + len(found)
            if k == i:
                numAnx = numAnx + 1         
print "The number of anxious emotion words in the real news articles:", (numAnx)

# counter for anger emotion in large sample without stop words
numAng = 0
for k in x['Anger']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numAng = numAng + len(found)
            if k == i:
                numAng = numAng + 1         
print "The number of anger emotion words in the real news articles:", (numAng)

# counter for sad emotion in large sample without stop words
numSad = 0
for k in x['Sad']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numSad = numSad + len(found)
            if k == i:
                numSad = numSad + 1         
print "The number of sad emotion words in the real news articles:", (numSad)

# counter for religious emotion in large sample without stop words
numRelig = 0
for k in x['Relig']:
    for i in wordsFiltered:
        if(k!=''):
            if(k.find('*')!=-1):
                hold = k.split("*")
                my_regex = r"" + re.escape(hold[0]) + r"[a-z]+"
                #found is a list of all words that match our regex
                found = re.findall(my_regex, i)
                numRelig = numRelig + len(found)
            if k == i:
                numRelig = numRelig + 1         
print "The number of religious emotion words in the real news articles:", (numRelig)
# Out:
# The number of pronouns in the real news articles: 2980
# The number of personal pronouns in the real news articles: 938
# The number of adverbs in the real news articles: 1140
# The number of positive emotion words in the real news articles: 975
# The number of negative emotion words in the real news articles: 773
# The number of anxious emotion words in the real news articles: 416
# The number of anger emotion words in the real news articles: 434
# The number of sad emotion words in the real news articles: 246
